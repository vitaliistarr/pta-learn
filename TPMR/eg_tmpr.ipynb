# %% [markdown]
# # 1. Import package

# %%
from tpmr import *
from ti_misc import *

# %% [markdown]
# # 2. Import data

# %%
data_path = 'F:/PhD/pta-learn/data'

df_bhp = pd.read_csv(data_path + '/ti_p.csv', index_col=0)
df_rate = pd.read_csv(data_path + '/ti_r.csv', index_col=0)

# change Timestamp to datetime
df_bhp['Timestamp'] = pd.to_datetime(df_bhp['Timestamp'])
df_rate['Timestamp'] = pd.to_datetime(df_rate['Timestamp'])

# %%
plot_whole(df_bhp, df_rate)

# %% [markdown]
# # 3. Transient Identification

# %% [markdown]
# ## 3.1 set parameters

# %%
# p is the relative pressure drop in a shut-in transient
p = 10

# interval is the minimum time duration in a shut-in transient
interval_shutin = 20

# %% [markdown]
# ## 3.2 TPMR calculation

# %%
shutin_bp_all, shutin_bp_interval, shutin_transient_all, shutin_transient_interval = TPMR(df_bhp, p, interval_shutin)

# %% [markdown]
# ## 3.3 Plot the results

# %%
# make a empty dataframe with the same columns as TI_results for visualization
TI_empty = pd.DataFrame(columns = shutin_transient_interval.columns)

# %%
plot_target(df_bhp, df_rate, shutin_transient_interval, TI_empty)
